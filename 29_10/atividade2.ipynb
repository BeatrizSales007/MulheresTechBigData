# %% [markdown]
# #ATIVIDADE 2: (GITHUB)
#
# Replique os processos de leitura, cópia e consultas exercitados em aula utilizando um dataset livre
# pesquisado por você (dê preferência a arquivos .csv, .xlsx ou .json).

# %%
import pandas as pd
import numpy as np

# %%
dados=pd.read_json('atividade2.json')
display(dados.head())
estatistica=dados.describe()
display(estatistica)
df_copia=dados.copy()
display(df_copia)
# Out:
#                                                                                                source  \
# Rendimento médio mensal real das pessoas de 14 ...  "IBGE - Pesquisa Nacional por Amostra de Domic...
# Variação percentual em relação a três trimestre...  "IBGE - Pesquisa Nacional por Amostra de Domic...
# Variação percentual em relação ao mesmo trimest...  "IBGE - Pesquisa Nacional por Amostra de Domic...
#
#                                                                                                 title  \
# Rendimento médio mensal real das pessoas de 14 ...  Rendimento médio mensal das pessoas de 14 anos...
# Variação percentual em relação a três trimestre...  Rendimento médio mensal das pessoas de 14 anos...
# Variação percentual em relação ao mesmo trimest...  Rendimento médio mensal das pessoas de 14 anos...
#
#                                                               valuesMap
# Rendimento médio mensal real das pessoas de 14 ...  {'Totais': '3.228'}
# ...
